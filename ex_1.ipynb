# %%
usernames=['Admin','Jason','Alex','Chris','Lee']
for username in usernames:
    if username=='Admin':
        print("Hello Admin, would you like to see a status report")
    else:
        print("Hello",username,", happy to see you here")
# Out:
# Hello Admin, would you like to see a status report
# Hello Jason , happy to see you here
# Hello Alex , happy to see you here
# Hello Chris , happy to see you here
# Hello Lee , happy to see you here
