# %%
import matplotlib.pyplot as plt
import numpy as np

# Fixing random state for reproducibility
np.random.seed(19680801)


plt.rcdefaults()
fig, ax = plt.subplots()

# Example data
people = ('Erwin Helmchen', 'Josef Bican', 'Ferenc Puskás', 'Cristiano Ronaldo', 'Ferenc Deák')
y_pos = np.arange(len(people))
goals = (982,942,808,795,794)
error = np.random.rand(len(people))

ax.barh(y_pos, performance, xerr=error, align='center')
ax.set_yticks(y_pos)
ax.set_yticklabels(people)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Goals')
ax.set_title('The best goalscorers')

for index, value in enumerate(goals):
    plt.text(value, index, str(value))
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
labels = ['English', 'Math', 'Social sciences', 'Science','Overall']
men_means = [3.12, 3.04, 3.27, 3.11, 3.07]
women_means = [3.38, 3.15, 3.39, 3.24, 3.24]

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, men_means, width, label='Males')
rects2 = ax.bar(x + width/2, women_means, width, label='Females')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Scores')
ax.set_title('GPA scores by subject and gender')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

fig.tight_layout()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
labels = 'Sleeping', 'Internet', 'studying', 'Eating','Others'
sizes = [35, 40, 10, 5,10]
explode = (0, 0.1, 0, 0,0)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
ax1.set_title('Average day of student')
# Out:
# Text(0.5, 1.0, 'Average day of student')

# %%
import matplotlib.pyplot as plt
import numpy as np
N = 5
leader = (45, 35, 38, 41, 25)
second = (35, 39, 21, 46, 50)
leadStd = (2, 3, 4, 1, 2)
secondStd = (3, 5, 2, 3, 3)
ind = np.arange(N)    # the x locations for the groups
width = 0.35       # the width of the bars: can also be len(x) sequence
fig, ax = plt.subplots()

p1 = ax.bar(ind, leader, width, yerr=leadStd, label='Team leader')
p2 = ax.bar(ind, second, width,
            bottom=leader, yerr=secondStd, label='Second teammate')

ax.axhline(0, color='grey', linewidth=0.8)
ax.set_ylabel('Scores')
ax.set_title('Scores by team and teammates')
ax.set_xticks(ind)
ax.set_xticklabels(('1st team', '2nd team', '3rd team', '4th team', '5th team'))
ax.legend()


plt.show()

# %%
year = [1965, 1970, 1980, 1990, 2000, 2010, 2019]
production_by_region = {
    'Middle East':[4860,8062,10862,9739,13129,14073,16484],
    'North Amerca':[5694,7300,7799,7612,7564,7995,12984],
    'CIS':[2824,4105,7014,6571,4567,7674,8314],
    'Africa': [1235.1,3399.63 , 3492.49, 3696.37, 4321.54, 5664.29, 4640.98],
    'Central and South Americas': [2630,2927,2264,2721,4010,4403,3686],
    'Europe': [453,488,1667,2595,3900,2323,1855],
    'Asia Pacific':[522,1148,2847,3791,4438,4691,4201]
}

fig, ax = plt.subplots()
ax.stackplot(year, production_by_region.values(),
             labels=production_by_region.keys())
ax.legend(loc='upper left')
ax.set_title('World oil production')
ax.set_xlabel('Year')
ax.set_ylabel('Amount of oil produced (TWh)')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.random.normal(55, 13, 1000)

plt.hist(x)
plt.title('Average mark distribution at WIUT')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(6, 3), subplot_kw=dict(aspect="equal"))

curriculum = ["12 h lectures",
              "24 h tutorials",
              "12 h workshops",
              "152 h self_study"]

data = [float(x.split()[0]) for x in curriculum]
lessons = [x.split()[-1] for x in curriculum]

def func(pct, allvals):
    absolute = int(round(pct/100.*np.sum(allvals)))
    return "{:.1f}%\n({:d} h)".format(pct, absolute)

wedges, texts, autotexts = ax.pie(data, autopct=lambda pct: func(pct, data),
                                  textprops=dict(color="w"))

ax.legend(wedges, lessons,
          title="Lesson types",
          loc="center left",
          bbox_to_anchor=(1, 0, 0.5, 1))

plt.setp(autotexts, size=8, weight="bold")

ax.set_title("Study curriculum at WIUT")

plt.show()

# %%
import matplotlib.pyplot as plt

data = {'apple': 1.75, 'orange': 3, 'lemon': 2, 'lime': 2.5}
names = list(data.keys())
values = list(data.values())

fig, axs = plt.subplots(1, 3, figsize=(9, 3), sharey=True)
axs[0].bar(names, values)
axs[1].scatter(names, values)
axs[2].plot(names, values)
fig.suptitle('Fruit Prices($)')
# Out:
# Text(0.5, 0.98, 'Fruit Prices($)')

# %%
import matplotlib.pyplot as plt 
labels = ['Kazakhstan', 'Russia', 'Uzbekistan']
values = [904,692,250]

bars = plt.bar(labels, values)
patterns = ['x','o','/']
for bar in bars:
    bar.set_hatch(patterns.pop())

# bars[0].set_hatch('x')
# bars[1].set_hatch('o')
# bars[2].set_hatch('/')

plt.title('Average Monthly Salary')
plt.xlabel('Countries')
plt.ylabel('US dollars')

plt.figure(figsize=(6,4))
                  
plt.show()

# %%
# Fixing random state for reproducibility
np.random.seed(19680801)


plt.rcdefaults()
fig, ax = plt.subplots()

# Example data
clubs= ('Atletico Madrid', 'Real Madrid', 'Barcelona', 'Sevilia')
y_pos = np.arange(len(clubs))
points = (83,81,76,74)
error = np.random.rand(len(clubs))

ax.barh(y_pos, points, xerr=error, align='center')
ax.set_yticks(y_pos)
ax.set_yticklabels(clubs)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Points')
ax.set_title('La Liga table')

for index, value in enumerate(points):
    plt.text(value, index, str(value))
plt.show()
