# %%
shopping_list = "{} {} {}"
grocery = "\n\t\tDairy\n\t\tBeef\n\t\tCarrots"
clean = "\n\t\tRubber gloves\n\t\tLiquid soap"
print("Here is my shopping list:\n\t*Groceries:",shopping_list.format(grocery,"\n\t*Cleaning goods",clean))
print("What else should I buy? ", end='')
product = input()#input some product name
def new_product(arg1):
    print(f"So I should also buy {arg1}")
new_product(product)
print("""Now I got all I need for shopping.
I can go now.
I'll be in no minute.""")
# Out:
# Here is my shopping list:
# 	*Groceries:
# 		Dairy
# 		Beef
# 		Carrots
# 	*Cleaning goods
# 		Rubber gloves
# 		Liquid soap
# What else should I buy? Apples
# So I should also buy Apples
# Now I got all I need for shopping.
# I can go now.
# I'll be in no minute.
